# %%
import pandas as pd

# %%
ls ZillowData/
# Out:
# Neighborhood_Zhvi_4bedroom.csv
# Zip_MedianListingPricePerSqft_AllHomes.csv
# Zip_MedianListingPrice_AllHomes.csv
# Zip_MedianSoldPricePerSqft_AllHomes.csv
# Zip_MedianSoldPrice_AllHomes.csv
# Zip_PctOfHomesDecreasingInValues_AllHomes.csv
# Zip_PctOfHomesIncreasingInValues_AllHomes.csv

# %%
df_4bedroom = pd.DataFrame.from_csv('ZillowData/Neighborhood_Zhvi_4bedroom.csv')

# %%
df = df_4bedroom.query('Metro=="San Francisco"').sort_values('City')
print(df)
pd.set_option('display.max_rows', 500)
# Out:
#                                         RegionName           City State  \
# RegionID
# 268395                                    Parkmont        Fremont    CA
# 274184                                Kimber-Gomes        Fremont    CA
# 268350                                   Northgate        Fremont    CA
# 268037                                    Cabrillo        Fremont    CA
# 268178                                    Glenmoor        Fremont    CA
# 273232                             Cherry-Guardino        Fremont    CA
# 275886                            Vineyards-Avalon        Fremont    CA
# 276637                                Warm Springs        Fremont    CA
# 268222                                   Irvington        Fremont    CA
# 268200                                     Grimmer        Fremont    CA
# 273179                                 Centerville        Fremont    CA
# 268046                              Canyon Heights        Fremont    CA
# ...

# %%
# Out:
# /Users/sofiatti/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#           SizeRank       1996-04       1996-05       1996-06       1996-07  \
# count  3108.000000  2.359000e+03  2.398000e+03  2.398000e+03  2.398000e+03
# mean   1554.500000  1.770891e+05  1.763852e+05  1.762417e+05  1.761900e+05
# std     897.346644  1.132661e+05  1.122956e+05  1.120938e+05  1.119547e+05
# min       1.000000  3.320000e+04  3.190000e+04  3.080000e+04  3.020000e+04
# 25%     777.750000           NaN           NaN           NaN           NaN
# 50%    1554.500000           NaN           NaN           NaN           NaN
# 75%    2331.250000           NaN           NaN           NaN           NaN
# max    3108.000000  1.309700e+06  1.317800e+06  1.320400e+06  1.333400e+06
#
#             1996-08       1996-09       1996-10       1996-11       1996-12  \
# ...

# %%
median_list_price_sqft = 'ZillowData/Zip_MedianListingPricePerSqft_AllHomes.csv'
median_list_price = 'ZillowData/Zip_MedianListingPrice_AllHomes.csv'
sold_price_sqft = 'ZillowData/Zip_MedianSoldPricePerSqft_AllHomes.csv'
sold_price = 'ZillowData/Zip_MedianSoldPrice_AllHomes.csv'
decreasing = 'ZillowData/Zip_PctOfHomesDecreasingInValues_AllHomes.csv'
increasing = 'ZillowData/Zip_PctOfHomesIncreasingInValues_AllHomes.csv'

# %%
df_median = pd.DataFrame.from_csv(median_list_price)
df_sold_price = pd.DataFrame.from_csv(sold_price)
df_decreasing = pd.DataFrame.from_csv(decreasing)
df_increasing = pd.DataFrame.from_csv(increasing)

# %%
df_increasing.head()
# Out:
#           RegionName           City State          Metro     CountyName  \
# RegionID
# 84654          60657        Chicago    IL        Chicago           Cook
# 84616          60614        Chicago    IL        Chicago           Cook
# 61616          10002       New York    NY       New York       New York
# 84640          60640        Chicago    IL        Chicago           Cook
# 97564          94109  San Francisco    CA  San Francisco  San Francisco
#
#           SizeRank  1997-02  1997-03  1997-04  1997-05   ...     2016-01  \
# RegionID                                                 ...
# 84654            1    72.85    73.39    73.92    66.30   ...       50.99
# 84616            2    81.77    80.52    73.04    74.61   ...       60.26
# 61616            3      NaN      NaN    73.11    70.04   ...       79.42
# 84640            4    56.07    59.23    60.83    53.06   ...       59.43
# 97564            5    72.61    76.79    78.73    72.72   ...       77.83
#
# ...

# %%
df_decreasing.head()
# Out:
#           RegionName           City State          Metro     CountyName  \
# RegionID
# 84654          60657        Chicago    IL        Chicago           Cook
# 84616          60614        Chicago    IL        Chicago           Cook
# 61616          10002       New York    NY       New York       New York
# 84640          60640        Chicago    IL        Chicago           Cook
# 97564          94109  San Francisco    CA  San Francisco  San Francisco
#
#           SizeRank  1997-02  1997-03  1997-04  1997-05   ...     2016-01  \
# RegionID                                                 ...
# 84654            1    21.91    22.86    22.61    29.77   ...       38.27
# 84616            2    15.09    16.55    22.58    21.23   ...       30.29
# 61616            3      NaN      NaN    25.68    28.75   ...       14.71
# 84640            4    39.83    35.52    34.23    42.85   ...       32.53
# 97564            5    23.55    19.37    16.92    23.49   ...       19.30
#
# ...

# %%
df_median_sqft = pd.DataFrame.from_csv(median_list_price)

# %%
df_median_sqft.query("Metro == 'San Francisco'")
# Out:
#                            City State          Metro     CountyName  SizeRank  \
# RegionName
# 94109             San Francisco    CA  San Francisco  San Francisco         8
# 94565                 Pittsburg    CA  San Francisco   Contra Costa        29
# 94110             San Francisco    CA  San Francisco  San Francisco        63
# 94536                   Fremont    CA  San Francisco        Alameda       165
# 94544                   Hayward    CA  San Francisco        Alameda       267
# 94509                   Antioch    CA  San Francisco   Contra Costa       279
# 94122             San Francisco    CA  San Francisco  San Francisco       296
# 94538                   Fremont    CA  San Francisco        Alameda       342
# 94541                   Hayward    CA  San Francisco        Alameda       351
# 94587                Union City    CA  San Francisco        Alameda       383
# 94080       South San Francisco    CA  San Francisco      San Mateo       434
# ...

# %%
list(df_median_list)
# Out:
# ['City',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '2010-01',
#  '2010-02',
#  '2010-03',
#  '2010-04',
#  '2010-05',
#  '2010-06',
#  '2010-07',
#  '2010-08',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
#  '2013-12',
#  '2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
# ...
